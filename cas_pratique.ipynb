# %% [markdown]
# # Donnees

# %%
import pandas as pd

df = pd.read_csv("MovieReview.csv")
display(df.head())
print(df.shape)

df = df.drop('sentiment', axis=1)
# Out:
#   sentiment                                             review
# 0  Positive  With all this stuff going down at the moment w...
# 1  Positive  'The Classic War of the Worlds' by Timothy Hin...
# 2  Negative  The film starts with a manager (Nicholas Bell)...
# 3  Negative  It must be assumed that those who praised this...
# 4  Positive  Superbly trashy and wondrously unpretentious 8...
# (25000, 2)

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download()
stop_words = stopwords.words('english')

# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)

    # remove stopword
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

df.review = df.review.apply(lambda x :preprocess_sentence(x))
df.head()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
#                                               review
# 0  stuff going moment started listening music wat...
# 1  classic war worlds timothy hines entertaining ...
# 2  film starts manager nicholas bell giving welco...
# 3  must assumed praised film greatest filmed oper...
# 4  superbly trashy wondrously unpretentious explo...

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download()
stop_words = stopwords.words('english')

# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)

    # remove stopword
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

df.review = df.review.apply(lambda x :preprocess_sentence(x))
df.head()

# %% [markdown]
# # Tokens

# %%
import tensorflow as tf
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df.review)
# Out:
# c:\Users\georg\OneDrive\Cours DataScientest\StreamLit\Cas Pratique Deep Learning\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
word2idx = tokenizer.word_index
idx2word = tokenizer.index_word
vocab_size = tokenizer.num_words

# %% [markdown]
# # Modelisation

# %%
import numpy as np


def sentenceToData(tokens, WINDOW_SIZE):
    window = np.concatenate((np.arange(-WINDOW_SIZE,0),np.arange(1,WINDOW_SIZE+1)))
    X,Y=([],[])
    for word_index, word in enumerate(tokens) :
        if ((word_index - WINDOW_SIZE >= 0) and (word_index + WINDOW_SIZE <= len(tokens) - 1)) :
            X.append(word)
            Y.append([tokens[word_index-i] for i in window])
    return X, Y


WINDOW_SIZE = 5

X, Y = ([], [])
for review in df.review:
    for sentence in review.split("."):
        word_list = tokenizer.texts_to_sequences([sentence])[0]
        if len(word_list) >= WINDOW_SIZE:
            Y1, X1 = sentenceToData(word_list, WINDOW_SIZE//2)
            X.extend(X1)
            Y.extend(Y1)
    
X = np.array(X).astype(int)
y = np.array(Y).astype(int).reshape([-1,1])

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D

embedding_dim = 300
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(GlobalAveragePooling1D())
model.add(Dense(vocab_size, activation='softmax'))

# %%
# Réduction de la taille du dataset pour test rapide
X_tiny = X[:10000]
y_tiny = y[:10000]

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_tiny, y_tiny, batch_size = 128, epochs=25)
# Out:
# Epoch 1/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.0171 - loss: 7.8217
# Epoch 2/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.0180 - loss: 7.5974
# Epoch 3/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0192 - loss: 7.4635
# Epoch 4/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.0199 - loss: 7.3445
# Epoch 5/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0226 - loss: 7.2238
# Epoch 6/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.0246 - loss: 7.0888
# Epoch 7/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.0323 - loss: 6.9327
# Epoch 8/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0411 - loss: 6.7502
# Epoch 9/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0531 - loss: 6.5402
# Epoch 10/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0694 - loss: 6.2997
# Epoch 11/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.0910 - loss: 6.0248
# Epoch 12/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.1195 - loss: 5.7151
# Epoch 13/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.1552 - loss: 5.3736
# Epoch 14/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.1960 - loss: 5.0026
# Epoch 15/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.2498 - loss: 4.6089
# Epoch 16/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3003 - loss: 4.2010
# Epoch 17/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.3629 - loss: 3.7888
# Epoch 18/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4258 - loss: 3.3835
# Epoch 19/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4909 - loss: 2.9925
# Epoch 20/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.5576 - loss: 2.6256
# Epoch 21/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6156 - loss: 2.2876
# Epoch 22/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.6807 - loss: 1.9817
# Epoch 23/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7410 - loss: 1.7093
# Epoch 24/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7908 - loss: 1.4704
# Epoch 25/25
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8366 - loss: 1.2623

# %% [markdown]
# # Sauvegarde du modèle

# %%
model.save("word2vec.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
